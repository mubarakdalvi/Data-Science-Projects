# %% [markdown]
# <a href="https://colab.research.google.com/github/mubarakdalvi/Data-Science-Projects/blob/main/MachineLearning_Interview_mock_test_Feb_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Usecase - 01 **Credit Card Fraud Detection using Logistic Regression** (Duration 25 minutes)
#
# You got a task from a financial institution that is concerned about credit card fraud. The goal is to develop a machine learning model using logistic regression to predict whether a credit card transaction is fraudulent or not based on various features.
#
#
# **Requirements:**
#
# 1. Load and explore the dataset to understand its structure and characteristics.
# 2. Preprocess the data, handling missing values, scaling numerical features, and encoding categorical variables if necessary.
# 3. Split the dataset into training and testing sets.
# 4. Build a logistic regression model to predict the likelihood of a transaction being fraudulent.
# 5. Evaluate the model's performance using appropriate metrics
# 6. Fine-tune the model parameters if needed to improve its performance.

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-23.1.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Installing collected packages: faker
# Successfully installed faker-23.1.0

# %%
# !pip install maxminddb-geolite2
# Out:
# Collecting maxminddb-geolite2
#   Downloading maxminddb-geolite2-2018.703.tar.gz (26.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 27.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting maxminddb (from maxminddb-geolite2)
#   Downloading maxminddb-2.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 4.3 MB/s eta 0:00:00
# Collecting setuptools>=68.2.2 (from maxminddb->maxminddb-geolite2)
#   Downloading setuptools-69.0.3-py3-none-any.whl (819 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 37.3 MB/s eta 0:00:00
# Building wheels for collected packages: maxminddb-geolite2
#   Building wheel for maxminddb-geolite2 (setup.py) ... done
#   Created wheel for maxminddb-geolite2: filename=maxminddb_geolite2-2018.703-py3-none-any.whl size=26407029 sha256=c862ef35aff74d7e025ed9318391152ba82e2075bbbd334ec0963a6a49d4163a
#   Stored in directory: /root/.cache/pip/wheels/a5/71/c0/8a053957754d9177cf23aec9927971f9ead13517426f0d63d3
# Successfully built maxminddb-geolite2
# Installing collected packages: setuptools, maxminddb, maxminddb-geolite2
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed maxminddb-2.5.2 maxminddb-geolite2-2018.703 setuptools-69.0.3

# %%
! pip install random_ip_generator
# Out:
# Collecting random_ip_generator
#   Downloading random_ip_generator-0.1.3-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.6 MB/s eta 0:00:00
# Collecting ipaddress (from random_ip_generator)
#   Downloading ipaddress-1.0.23-py2.py3-none-any.whl (18 kB)
# Installing collected packages: ipaddress, random_ip_generator
# Successfully installed ipaddress-1.0.23 random_ip_generator-0.1.3

# %%
! pip install pip pycountry
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (23.1.2)
# Collecting pycountry
#   Downloading pycountry-23.12.11-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 15.0 MB/s eta 0:00:00
# Installing collected packages: pycountry
# Successfully installed pycountry-23.12.11

# %%
import random
import pandas as pd
import numpy as np
from faker import Faker
from datetime import datetime,time
from geolite2 import geolite2
import pycountry
from random_ip_generator import random_ip_for_country
import ipaddress
import re
from sklearn.preprocessing import LabelEncoder

# %%
fake = Faker('en-IN')

# %% [markdown]
# have to map one credit card to one user there will be not duplicate , we can use set()

# %% [markdown]
# Card Number, Expiration Date, CVV/CVC, Cardholder Name, Billing Address, normal ip address, suspisious ip address, amount frequency, high  transaction amount,suspicious sites where user had visisted, whether user have enabled 2fa or not, customer alert, card type

# %%
Visa_creditCard = set()
MasterCard_creditCard = set()
Amex_creditCard = set()
Discover_creditCard = set()
def generate_card_number():
    i = 0
    while i < 4000000:
        card_type = random.choice(['Visa', 'MasterCard', 'Amex', 'Discover'])
        if card_type == 'Visa':
            Visa_creditCard.add(random.randint(4000000000000000, 4999999999999999))
        elif card_type == 'MasterCard':
            MasterCard_creditCard.add(random.randint(5000000000000000, 5999999999999999))
        elif card_type == 'Amex':
            Amex_creditCard.add(random.choice([random.randint(400000000000000, 499999999999999), random.randint(700000000000000, 799999999999999)]))
        elif card_type == 'Discover':
            Discover_creditCard.add(random.randint(6000000000000000, 6999999999999999))
        i += 1
print(generate_card_number())
# Out:
# None

# %%
countries = [country.name for country in pycountry.countries]
Country_ip = []
country_name = []
i = 0
while i < 1000:
  try:
    sus_countries = random.choice(countries)
    ip_from_sus_country = random_ip_for_country(pycountry.countries.get(name=sus_countries).alpha_2)
    ip_str = str(ip_from_sus_country)
    Country_ip.append(ip_str),country_name.append(sus_countries)
    i += 1
  except ValueError:
    print(f'Error Code : {sus_countries}')
print(len(Country_ip),Country_ip,len(country_name),country_name)
# Out:
# Error Code : South Georgia and the South Sandwich Islands
# Error Code : Cocos (Keeling) Islands
# Error Code : Christmas Island
# Error Code : Heard Island and McDonald Islands
# Error Code : Christmas Island
# Error Code : Christmas Island
# Error Code : Cocos (Keeling) Islands
# Error Code : Cocos (Keeling) Islands
# Error Code : Christmas Island
# Error Code : South Georgia and the South Sandwich Islands
# Error Code : Cocos (Keeling) Islands
# Error Code : South Georgia and the South Sandwich Islands
# Error Code : South Georgia and the South Sandwich Islands
# Error Code : Heard Island and McDonald Islands
# Error Code : Christmas Island
# Error Code : Cocos (Keeling) Islands
# Error Code : Western Sahara
# Error Code : Saint Helena, Ascension and Tristan da Cunha
# Error Code : Cocos (Keeling) Islands
# Error Code : Heard Island and McDonald Islands
# Error Code : Christmas Island
# Error Code : South Georgia and the South Sandwich Islands
# Error Code : Saint Helena, Ascension and Tristan da Cunha
# Error Code : Saint Helena, Ascension and Tristan da Cunha
# Error Code : Cocos (Keeling) Islands
# Error Code : Christmas Island
# Error Code : Cocos (Keeling) Islands
# Error Code : Heard Island and McDonald Islands
# Error Code : Western Sahara
# Error Code : Heard Island and McDonald Islands
# 1000 ['103.16.15.205', '162.158.149.116', '167.167.194.209', '196.197.177.115', '144.120.64.229', '206.0.18.164', '173.239.197.82', '103.239.104.117', '185.193.240.235', '195.64.112.193', '197.211.106.24', '196.223.27.166', '202.43.12.3', '91.190.99.104', '103.242.126.45', '103.143.246.121', '45.117.197.12', '176.32.194.21', '196.196.125.136', '196.197.51.222', '41.74.78.255', '156.229.50.96', '103.244.189.52', '103.1.98.156', '193.232.92.134', '195.234.199.86', '95.210.5.95', '91.199.237.195', '203.192.170.124', '200.119.223.71', '37.72.134.239', '103.190.11.169', '196.197.113.202', '77.94.36.108', '102.217.98.124', '93.171.174.156', '80.66.79.182', '170.254.65.37', '138.118.9.136', '84.254.152.234', '131.100.31.103', '147.185.253.67', '154.73.115.199', '197.157.247.153', '199.96.64.198', '207.209.189.168', '196.199.193.241', '196.60.94.111', '198.161.171.148', '102.64.102.62', '202.65.37.69', '80.245.33.75', '37.153.184.59', '41.78.216.251', '143.0.34.120', '117.103.94.91', '185.96.230.249', '45.7.44.29', '193.22.144.126', '91.220.236.247', '196.199.170.31', '64.86.76.99', '185.152.29.238', '84.254.160.165', '207.248.78.176', '196.197.166.23', '95.210.56.238', '91.199.38.244', '139.91.177.209', '91.242.57.41', '101.101.62.248', '181.177.217.215', '192.107.177.76', '203.104.31.118', '146.70.145.224', '82.114.160.156', '70.36.9.247', '41.78.238.162', '93.189.161.215', '102.38.51.51', '103.159.209.202', '23.141.216.144', '213.131.94.8', '24.155.28.104', '209.27.142.45', '201.220.11.60', '197.234.84.129', '41.215.253.13', '103.132.247.45', '185.242.20.73', '80.12.240.18', '178.248.140.111', '103.158.149.140', '154.73.50.156', '41.223.202.117', '192.145.180.141', '128.201.0.95', '109.122.136.124', '77.70.142.197', '149.13.31.55', '103.220.0.198', '181.214.159.114', '103.158.229.106', '2.17.201.94', '185.182.10.168', '46.151.56.164', '172.69.157.191', '185.77.39.49', '193.0.157.78', '203.91.171.90', '94.26.69.2', '103.237.80.37', '154.72.54.66', '160.224.214.72', '196.197.204.227', '203.29.217.170', '179.63.10.20', '213.157.116.137', '202.90.250.247', '95.46.156.160', '172.69.219.88', '91.199.53.225', '190.97.106.217', '185.166.58.59', '196.197.86.232', '185.67.174.179', '149.112.20.157', '201.220.202.124', '185.174.156.83', '141.179.93.42', '103.140.179.165', '2.56.143.124', '213.204.54.112', '80.15.251.33', '102.223.26.80', '91.245.222.196', '185.170.222.116', '87.121.69.254', '41.215.216.174', '84.254.160.205', '196.199.84.177', '103.111.28.191', '62.12.52.197', '198.145.230.102', '102.218.1.58', '105.235.211.97', '208.127.21.110', '23.130.168.26', '194.0.40.252', '195.139.169.200', '202.58.249.218', '138.36.24.8', '104.29.19.254', '199.0.86.48', '103.106.64.156', '57.98.101.122', '103.101.192.241', '196.199.56.182', '113.197.69.75', '45.85.234.62', '192.30.124.19', '200.115.120.168', '119.252.228.112', '206.83.127.153', '93.121.202.251', '94.190.144.8', '103.143.183.103', '45.154.228.81', '196.198.201.112', '203.24.106.215', '80.89.181.26', '188.255.208.245', '103.21.251.102', '142.54.199.224', '196.8.217.47', '196.199.160.135', '154.72.16.9', '52.123.159.31', '146.120.128.247', '41.222.65.179', '185.2.87.58', '205.252.251.155', '196.60.110.194', '76.76.191.253', '103.29.90.202', '195.8.8.120', '193.22.230.31', '185.21.138.161', '45.71.156.4', '91.212.24.98', '41.202.216.132', '27.96.25.82', '185.22.47.13', '24.155.28.131', '193.163.183.2', '213.209.163.204', '163.116.166.253', '194.169.168.164', '146.120.34.35', '41.223.188.135', '41.77.219.228', '117.20.32.158', '43.243.176.204', '193.149.150.11', '103.9.20.143', '197.255.225.54', '196.8.227.101', '80.88.2.70', '185.65.174.254', '196.43.214.253', '94.46.206.156', '104.244.229.46', '41.242.118.112', '41.223.187.144', '84.254.163.70', '172.225.239.86', '87.119.142.125', '41.194.34.244', '194.0.39.239', '190.120.217.132', '103.122.73.119', '129.222.56.21', '191.101.58.240', '201.219.227.107', '69.79.127.153', '41.216.174.253', '212.30.3.121', '103.17.112.204', '151.101.247.209' ...

# %%
transaction_day = []
def if_leap():
  for i in range(1,1001):
    month,year = random.randint(1,12), random.randint(2023,2024)
    if month == 2:
      if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
        day = random.randint(1,29)
      else:
        day = random.randint(1,28)
    elif month in [4,6,9,11]:
      day = random.randint(1,30)
    else:
      day = random.randint(1,31)
    date = datetime(year,month,day)
    date_app = date.strftime('%d/%m/%Y')
    transaction_day.append(date_app)
print(if_leap())
# Out:
# None

# %%
suspected_users = []
def is_suspicious():
  try:
    geo = geolite2.reader()
    for  i in range(1000):
      ip_india = f'{59}.{181}.{20}.{random.randint(0,255)}'
      india_country = [geo.get(ip_india)['country']['names']['en']] if geo.get(ip_india) and 'country' in geo.get(ip_india) else []
      sus_countries = random.choice(country_name)
      ip_from_sus_country = random.choice(Country_ip)
      Billing_Address = fake.address()
      provided_address = fake.address()
      Two_FA = random.choice(['yes','no'])
      sus_transaction_time = random.choice([time(random.randint(2,5),random.randint(0,59),random.randint(0,59)).strftime('%I:%M:%S %p')])
      users_frequent_timeofpurchse = time(random.randint(19,23),random.randint(0,59),random.randint(0,59)).strftime('%I:%M:%S: %p')
      high_transaction_after_suspicion = random.choice(['yes','no'])
      customer_alert = random.choice(['yes','no'])
      trandaction_location = fake.address()
      current_location = fake.address()
      using_vpn = random.choice(['yes','no'])
      failed_logins = random.randint(0, 5)
      otp = fake.random_number(digits=6,fix_len=True)
      transaction = random.choice(transaction_day)
      transaction_date = transaction
      is_sus = []
      if ip_india != ip_from_sus_country and using_vpn == 'yes':
        if sus_transaction_time != users_frequent_timeofpurchse:
            if high_transaction_after_suspicion == 'yes' and Two_FA == 'no':
                if 3 <= failed_logins <= 5:
                    is_sus.append('yes')
                else:
                    is_sus.append('no')
            else:
              is_sus.append('no')
        else:
          is_sus.append('no')
      else:
        is_sus.append('no')
      suspected_users.append({
          'Billing_Address' : Billing_Address,
          'provided_address' : provided_address,
          'ip_india' : ip_india,
          'india_country' : india_country,
          'ip_from_sus_country' : ip_from_sus_country,
          'sus_countries' : sus_countries,
          'Two_FA' : Two_FA,
          'sus_transaction_time' : sus_transaction_time,
          'users_frequent_timeofpurchse' : users_frequent_timeofpurchse,
          'high_transaction_after_suspicion' : high_transaction_after_suspicion,
          'customer_alert' : customer_alert,
          'trandaction_location' : trandaction_location,
          'current_location' : current_location,
          'using_vpn' : using_vpn,
          'failed_logins' : failed_logins,
          'otp' : otp,
          'is_sus' : is_sus,
          'transaction_date' : transaction
          })
  except Exception as e:
    print(f'Error Code : {e}')
  return suspected_users
print(is_suspicious())
# Out:
# [{'Billing_Address': '30/90, Dada Street, Tadipatri-478733', 'provided_address': 'H.No. 153, Kashyap Zila\nKanpur-728548', 'ip_india': '59.181.20.102', 'india_country': ['India'], 'ip_from_sus_country': '102.135.229.167', 'sus_countries': 'Nepal', 'Two_FA': 'yes', 'sus_transaction_time': '05:42:37 AM', 'users_frequent_timeofpurchse': '08:27:01: PM', 'high_transaction_after_suspicion': 'yes', 'customer_alert': 'yes', 'trandaction_location': '640, Mahajan Zila\nNanded-609745', 'current_location': '862\nSeth Chowk, Vasai-Virar-530922', 'using_vpn': 'yes', 'failed_logins': 4, 'otp': 931590, 'is_sus': ['no'], 'transaction_date': '26/04/2024'}, {'Billing_Address': 'H.No. 10, Subramaniam Chowk\nHubli–Dharwad 740342', 'provided_address': 'H.No. 21\nChakrabarti Ganj\nMorbi 826771', 'ip_india': '59.181.20.249', 'india_country': ['India'], 'ip_from_sus_country': '176.32.194.21', 'sus_countries': 'Indonesia', 'Two_FA': 'yes', 'sus_transaction_time': '03:17:23 AM', 'users_frequent_timeofpurchse': '07:43:38: PM', 'high_transaction_after_suspicion': 'no', 'customer_alert': 'yes', 'trandaction_location': '34, Doshi\nSasaram-922659', 'current_location': '23/392, Dewan Path\nOngole-526288', 'using_vpn': 'no', 'failed_logins': 0, 'otp': 573006, 'is_sus': ['no'], 'transaction_date': '22/03/2024'}, {'Billing_Address': '12/10, Upadhyay Street\nArrah 097809', 'provided_address': 'H.No. 56, Krishna Path, Thrissur-511622', 'ip_india': '59.181.20.66', 'india_country': ['India'], 'ip_from_sus_country': '176.58.234.43', 'sus_countries': 'Spain', 'Two_FA': 'no', 'sus_transaction_time': '03:22:21 AM', 'users_frequent_timeofpurchse': '09:14:59: PM', 'high_transaction_after_suspicion': 'no', 'customer_alert': 'no', 'trandaction_location': '33/64, Bhatt Circle\nChinsurah-981958', 'current_location': 'H.No. 90, Chauhan Chowk, Gopalpur-016300', 'using_vpn': 'no', 'failed_logins': 4, 'otp': 828902, 'is_sus': ['no'], 'transaction_date': '24/08/2023'}, {'Billing_Address': 'H.No. 31, Chad Chowk\nKollam-837444', 'provided_address': '757\nDhawan Ganj\nBhubaneswar 919257', 'ip_india': '59.181.20.77', 'india_country': ['India'], 'ip_from_sus_country': '103.9.20.143', 'sus_countries': 'Mauritania', 'Two_FA': 'yes', 'sus_transaction_time': '05:19:36 AM', 'users_frequent_timeofpurchse': '08:37:42: PM', 'high_transaction_after_suspicion': 'yes', 'customer_alert': 'no', 'trandaction_location': 'H.No. 193, Madan Street, Salem 069835', 'current_location': '00/25\nBalakrishnan Marg, Kottayam-592636', 'using_vpn': 'yes', 'failed_logins': 4, 'otp': 693815, 'is_sus': ['no'], 'transaction_date': '20/02/2023'}, {'Billing_Address': '08/44, Luthra, Bhind-671342', 'provided_address': 'H.No. 837, Goyal Zila\nSultan Pur Majra 226998', 'ip_india': '59.181.20.184', 'india_country': ['India'], 'ip_from_sus_country': '213.157.116.137', 'sus_countries': 'Georgia', 'Two_FA': 'no', 'sus_transaction_time': '04:07:13 AM', 'users_frequent_timeofpurchse': '11:01:52: PM', 'high_transaction_after_suspicion': 'no', 'customer_alert': 'no', 'trandaction_location': 'H.No. 53\nAnand Nagar\nMiryalaguda-210843', 'current_location': '099\nDhar Chowk\nNagaon-845031', 'using_vpn': 'no', 'failed_logins': 0, 'otp': 950565, 'is_sus': ['no'], 'transaction_date': '21/04/2024'}, {'Billing_Address': '37/94, Lad Circle, Berhampore-110911', 'provided_address': 'H.No. 265, Srinivasan Path, Raebareli-103411', 'ip_india': '59.181.20.163', 'india_country': ['India'], 'ip_from_sus_country': '196.223.12.35', 'sus_countries': 'Jersey', 'Two_FA': 'no', 'sus_transaction_time': '02:32:28 AM', 'users_frequent_timeofpurchse': '08:24:57: PM', 'high_transaction_after_suspicion': 'yes', 'customer_alert': 'no', 'trandaction_location': '38/83\nBhatia Chowk\nKozhikode-501579', 'current_location': '22\nYogi\nMachilipatnam-603175', 'using_vpn': 'yes', 'failed_logins': 5, 'otp': 932526, 'is_sus': ['yes'], 'transaction_date': '21/03/2023'}, {'Billing_Address': '04/173, Raval Ganj\nRajpur Sonarpur 893349', 'provided_address': '06, Shere\nBh ...

# %%
creditcard_info = []
def creditcard_data():
  i = 0
  while i < 1000:
    card_type = random.choice(['Visa','MasterCard','Amex','Discover'])
    Expiration_Date = fake.credit_card_expire(start='now',end='+10y',date_format='%m/%y')
    CVV = fake.random_number(digits=3,fix_len=True)
    Cardholder_Name = fake.name()
    Cards = None
    if card_type == 'Visa':
      Cards = random.choice(list(Visa_creditCard))
    elif card_type == 'MasterCard':
      Cards = random.choice(list(MasterCard_creditCard))
    elif card_type == 'Amex':
      Cards = random.choice(list(Amex_creditCard))
    elif card_type == 'Discover':
      Cards = random.choice(list(Discover_creditCard))
    creditcard_info.append({
        'Cardholder_Name' : Cardholder_Name,
        'Cards' : Cards,
        'card_type' : card_type,
        'CVV' : CVV,
        'Expiration_Date' : Expiration_Date,
        })
    i += 1
  return creditcard_info
print(creditcard_data())
# Out:
# [{'Cardholder_Name': 'Rati Tiwari', 'Cards': 6546099441350552, 'card_type': 'Discover', 'CVV': 754, 'Expiration_Date': '01/30'}, {'Cardholder_Name': 'Arhaan Khanna', 'Cards': 784583187156598, 'card_type': 'Amex', 'CVV': 506, 'Expiration_Date': '02/26'}, {'Cardholder_Name': 'Azad Ramanathan', 'Cards': 5028206635783287, 'card_type': 'MasterCard', 'CVV': 166, 'Expiration_Date': '11/25'}, {'Cardholder_Name': 'Tarini Subramaniam', 'Cards': 5024780707162631, 'card_type': 'MasterCard', 'CVV': 393, 'Expiration_Date': '12/29'}, {'Cardholder_Name': 'Ira Kari', 'Cards': 6318291234876032, 'card_type': 'Discover', 'CVV': 867, 'Expiration_Date': '12/29'}, {'Cardholder_Name': 'Anahi Venkatesh', 'Cards': 6043692790936470, 'card_type': 'Discover', 'CVV': 859, 'Expiration_Date': '12/32'}, {'Cardholder_Name': 'Bhamini Choudhary', 'Cards': 5234150341444280, 'card_type': 'MasterCard', 'CVV': 345, 'Expiration_Date': '08/30'}, {'Cardholder_Name': 'Ishita Dugal', 'Cards': 5890604144231187, 'card_type': 'MasterCard', 'CVV': 297, 'Expiration_Date': '03/29'}, {'Cardholder_Name': 'Keya Guha', 'Cards': 6471876231806414, 'card_type': 'Discover', 'CVV': 596, 'Expiration_Date': '01/26'}, {'Cardholder_Name': 'Ishita Sarraf', 'Cards': 5616689472401631, 'card_type': 'MasterCard', 'CVV': 404, 'Expiration_Date': '04/25'}, {'Cardholder_Name': 'Bhavin Brahmbhatt', 'Cards': 6608940280847242, 'card_type': 'Discover', 'CVV': 410, 'Expiration_Date': '08/31'}, {'Cardholder_Name': 'Siya Ratta', 'Cards': 6455918432706241, 'card_type': 'Discover', 'CVV': 827, 'Expiration_Date': '07/28'}, {'Cardholder_Name': 'Neysa Solanki', 'Cards': 5865958623710278, 'card_type': 'MasterCard', 'CVV': 153, 'Expiration_Date': '10/32'}, {'Cardholder_Name': 'Tara Sodhi', 'Cards': 6616458101981514, 'card_type': 'Discover', 'CVV': 687, 'Expiration_Date': '12/30'}, {'Cardholder_Name': 'Rhea Garg', 'Cards': 4793351937376079, 'card_type': 'Visa', 'CVV': 576, 'Expiration_Date': '08/31'}, {'Cardholder_Name': 'Ivana Chokshi', 'Cards': 4927942551822016, 'card_type': 'Visa', 'CVV': 568, 'Expiration_Date': '06/33'}, {'Cardholder_Name': 'Fateh Deshmukh', 'Cards': 5125911232822618, 'card_type': 'MasterCard', 'CVV': 250, 'Expiration_Date': '05/26'}, {'Cardholder_Name': 'Badal Bakshi', 'Cards': 779295166557520, 'card_type': 'Amex', 'CVV': 110, 'Expiration_Date': '12/29'}, {'Cardholder_Name': 'Sara Date', 'Cards': 4407996670596186, 'card_type': 'Visa', 'CVV': 994, 'Expiration_Date': '07/31'}, {'Cardholder_Name': 'Advika Mammen', 'Cards': 6648783412975419, 'card_type': 'Discover', 'CVV': 377, 'Expiration_Date': '03/26'}, {'Cardholder_Name': 'Nirvi Ghose', 'Cards': 786868075694363, 'card_type': 'Amex', 'CVV': 353, 'Expiration_Date': '07/33'}, {'Cardholder_Name': 'Divyansh Sharaf', 'Cards': 494976504154769, 'card_type': 'Amex', 'CVV': 634, 'Expiration_Date': '03/29'}, {'Cardholder_Name': 'Sana Sanghvi', 'Cards': 4588767441223998, 'card_type': 'Visa', 'CVV': 593, 'Expiration_Date': '01/26'}, {'Cardholder_Name': 'Mamooty Zacharia', 'Cards': 417127736691383, 'card_type': 'Amex', 'CVV': 609, 'Expiration_Date': '07/24'}, {'Cardholder_Name': 'Khushi Ramanathan', 'Cards': 6737244947446114, 'card_type': 'Discover', 'CVV': 912, 'Expiration_Date': '08/26'}, {'Cardholder_Name': 'Pranay Upadhyay', 'Cards': 4183973051737022, 'card_type': 'Visa', 'CVV': 429, 'Expiration_Date': '07/24'}, {'Cardholder_Name': 'Madhav Loke', 'Cards': 5065238696681227, 'card_type': 'MasterCard', 'CVV': 132, 'Expiration_Date': '08/25'}, {'Cardholder_Name': 'Faiyaz Jaggi', 'Cards': 4571334053725223, 'card_type': 'Visa', 'CVV': 730, 'Expiration_Date': '03/26'}, {'Cardholder_Name': 'Vidur Chad', 'Cards': 4169678965959985, 'card_type': 'Visa', 'CVV': 673, 'Expiration_Date': '04/31'}, {'Cardholder_Name': 'Anahi Gulati', 'Cards': 755116332141043, 'card_type': 'Amex', 'CVV': 490, 'Expiration_Date': '06/32'}, {'Cardholder_Name': 'Saanvi Gaba', 'Cards': 4602672125438255, 'card_type': 'Visa', 'CVV': 661, 'Expiration_Date': '09/31'}, {'Cardholder_Name': 'Divi ...

# %%
sus = pd.DataFrame(creditcard_info)
sus.to_csv('customer_data')

# %%
bus = pd.DataFrame(suspected_users)
bus.to_csv('parameter')

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df_customer_data = pd.read_csv('customer_data',index_col=0)
df_customer_data.head()
# Out:
#       Cardholder_Name             Cards   card_type  CVV Expiration_Date
# 0         Rati Tiwari  6546099441350552    Discover  754           01/30
# 1       Arhaan Khanna   784583187156598        Amex  506           02/26
# 2     Azad Ramanathan  5028206635783287  MasterCard  166           11/25
# 3  Tarini Subramaniam  5024780707162631  MasterCard  393           12/29
# 4            Ira Kari  6318291234876032    Discover  867           12/29

# %%
df_customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Cardholder_Name  1000 non-null   object
#  1   Cards            1000 non-null   int64
#  2   card_type        1000 non-null   object
#  3   CVV              1000 non-null   int64
#  4   Expiration_Date  1000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 46.9+ KB

# %%
df_customer_data.corr()
# Out:
# <ipython-input-18-18b6cf2b05d7>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_customer_data.corr()
#           Cards       CVV
# Cards  1.000000  0.001103
# CVV    0.001103  1.000000

# %%
df_parameter = pd.read_csv('parameter',index_col=0)

# %%
df_parameter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Billing_Address                   1000 non-null   object
#  1   provided_address                  1000 non-null   object
#  2   ip_india                          1000 non-null   object
#  3   india_country                     1000 non-null   object
#  4   ip_from_sus_country               1000 non-null   object
#  5   sus_countries                     1000 non-null   object
#  6   Two_FA                            1000 non-null   object
#  7   sus_transaction_time              1000 non-null   object
#  8   users_frequent_timeofpurchse      1000 non-null   object
#  9   high_transaction_after_suspicion  1000 non-null   object
#  10  customer_alert                    1000 non-null   object
#  11  trandaction_location              1000 non-null   object
#  12  current_location                  1000 non-null   object
#  13  using_vpn                         1000 non-null   object
#  14  failed_logins                     1000 non-null   int64
#  15  otp                               1000 non-null   int64
#  16  is_sus                            1000 non-null   object
#  17  transaction_date                  1000 non-null   object
# dtypes: int64(2), object(16)
# memory usage: 148.4+ KB

# %%
india_country = df_parameter['india_country'].str.replace("\\['",'').str.replace("\\']",'')
# Out:
# <ipython-input-21-e451bb6feb13>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   india_country = df_parameter['india_country'].str.replace("\\['",'').str.replace("\\']",'')

# %%
df_parameter['india_country'] = india_country

# %%
df_parameter.head()
# Out:
#                                      Billing_Address  \
# 0               30/90, Dada Street, Tadipatri-478733
# 1  H.No. 10, Subramaniam Chowk\nHubli–Dharwad 740342
# 2               12/10, Upadhyay Street\nArrah 097809
# 3                H.No. 31, Chad Chowk\nKollam-837444
# 4                        08/44, Luthra, Bhind-671342
#
#                                  provided_address       ip_india  \
# 0          H.No. 153, Kashyap Zila\nKanpur-728548  59.181.20.102
# 1        H.No. 21\nChakrabarti Ganj\nMorbi 826771  59.181.20.249
# 2         H.No. 56, Krishna Path, Thrissur-511622   59.181.20.66
# 3            757\nDhawan Ganj\nBhubaneswar 919257   59.181.20.77
# 4  H.No. 837, Goyal Zila\nSultan Pur Majra 226998  59.181.20.184
#
#   india_country ip_from_sus_country sus_countries Two_FA sus_transaction_time  \
# 0         India     102.135.229.167         Nepal    yes          05:42:37 AM
# 1         India       176.32.194.21     Indonesia    yes          03:17:23 AM
# 2         India       176.58.234.43         Spain     no          03:22:21 AM
# 3         India        103.9.20.143    Mauritania    yes          05:19:36 AM
# 4         India     213.157.116.137       Georgia     no          04:07:13 AM
#
#   users_frequent_timeofpurchse high_transaction_after_suspicion  \
# 0                 08:27:01: PM                              yes
# 1                 07:43:38: PM                               no
# 2                 09:14:59: PM                               no
# 3                 08:37:42: PM                              yes
# 4                 11:01:52: PM                               no
#
#   customer_alert                       trandaction_location  \
# 0            yes           640, Mahajan Zila\nNanded-609745
# 1            yes                  34, Doshi\nSasaram-922659
# 2             no      33/64, Bhatt Circle\nChinsurah-981958
# 3             no      H.No. 193, Madan Street, Salem 069835
# 4             no  H.No. 53\nAnand Nagar\nMiryalaguda-210843
#
#                             current_location using_vpn  failed_logins     otp  \
# 0        862\nSeth Chowk, Vasai-Virar-530922       yes              4  931590
# 1          23/392, Dewan Path\nOngole-526288        no              0  573006
# 2   H.No. 90, Chauhan Chowk, Gopalpur-016300        no              4  828902
# 3  00/25\nBalakrishnan Marg, Kottayam-592636       yes              4  693815
# 4             099\nDhar Chowk\nNagaon-845031        no              0  950565
#
#    is_sus transaction_date
# 0  ['no']       26/04/2024
# 1  ['no']       22/03/2024
# 2  ['no']       24/08/2023
# 3  ['no']       20/02/2023
# 4  ['no']       21/04/2024

# %%
is_sus = df_parameter['is_sus'].str.replace("\\['",'').str.replace("\\']",'')
# Out:
# <ipython-input-24-afb991f6c0bb>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   is_sus = df_parameter['is_sus'].str.replace("\\['",'').str.replace("\\']",'')

# %%
df_parameter['is_sus'] = is_sus

# %%
df_parameter.head()
# Out:
#                                      Billing_Address  \
# 0               30/90, Dada Street, Tadipatri-478733
# 1  H.No. 10, Subramaniam Chowk\nHubli–Dharwad 740342
# 2               12/10, Upadhyay Street\nArrah 097809
# 3                H.No. 31, Chad Chowk\nKollam-837444
# 4                        08/44, Luthra, Bhind-671342
#
#                                  provided_address       ip_india  \
# 0          H.No. 153, Kashyap Zila\nKanpur-728548  59.181.20.102
# 1        H.No. 21\nChakrabarti Ganj\nMorbi 826771  59.181.20.249
# 2         H.No. 56, Krishna Path, Thrissur-511622   59.181.20.66
# 3            757\nDhawan Ganj\nBhubaneswar 919257   59.181.20.77
# 4  H.No. 837, Goyal Zila\nSultan Pur Majra 226998  59.181.20.184
#
#   india_country ip_from_sus_country sus_countries Two_FA sus_transaction_time  \
# 0         India     102.135.229.167         Nepal    yes          05:42:37 AM
# 1         India       176.32.194.21     Indonesia    yes          03:17:23 AM
# 2         India       176.58.234.43         Spain     no          03:22:21 AM
# 3         India        103.9.20.143    Mauritania    yes          05:19:36 AM
# 4         India     213.157.116.137       Georgia     no          04:07:13 AM
#
#   users_frequent_timeofpurchse high_transaction_after_suspicion  \
# 0                 08:27:01: PM                              yes
# 1                 07:43:38: PM                               no
# 2                 09:14:59: PM                               no
# 3                 08:37:42: PM                              yes
# 4                 11:01:52: PM                               no
#
#   customer_alert                       trandaction_location  \
# 0            yes           640, Mahajan Zila\nNanded-609745
# 1            yes                  34, Doshi\nSasaram-922659
# 2             no      33/64, Bhatt Circle\nChinsurah-981958
# 3             no      H.No. 193, Madan Street, Salem 069835
# 4             no  H.No. 53\nAnand Nagar\nMiryalaguda-210843
#
#                             current_location using_vpn  failed_logins     otp  \
# 0        862\nSeth Chowk, Vasai-Virar-530922       yes              4  931590
# 1          23/392, Dewan Path\nOngole-526288        no              0  573006
# 2   H.No. 90, Chauhan Chowk, Gopalpur-016300        no              4  828902
# 3  00/25\nBalakrishnan Marg, Kottayam-592636       yes              4  693815
# 4             099\nDhar Chowk\nNagaon-845031        no              0  950565
#
#   is_sus transaction_date
# 0     no       26/04/2024
# 1     no       22/03/2024
# 2     no       24/08/2023
# 3     no       20/02/2023
# 4     no       21/04/2024

# %%
df_parameter['is_sus'].value_counts()
# Out:
# no     940
# yes     60
# Name: is_sus, dtype: int64

# %%
df = df_customer_data.join(df_parameter,how='inner')

# %%
df.head()
# Out:
#       Cardholder_Name             Cards   card_type  CVV Expiration_Date  \
# 0         Rati Tiwari  6546099441350552    Discover  754           01/30
# 1       Arhaan Khanna   784583187156598        Amex  506           02/26
# 2     Azad Ramanathan  5028206635783287  MasterCard  166           11/25
# 3  Tarini Subramaniam  5024780707162631  MasterCard  393           12/29
# 4            Ira Kari  6318291234876032    Discover  867           12/29
#
#                                      Billing_Address  \
# 0               30/90, Dada Street, Tadipatri-478733
# 1  H.No. 10, Subramaniam Chowk\nHubli–Dharwad 740342
# 2               12/10, Upadhyay Street\nArrah 097809
# 3                H.No. 31, Chad Chowk\nKollam-837444
# 4                        08/44, Luthra, Bhind-671342
#
#                                  provided_address       ip_india  \
# 0          H.No. 153, Kashyap Zila\nKanpur-728548  59.181.20.102
# 1        H.No. 21\nChakrabarti Ganj\nMorbi 826771  59.181.20.249
# 2         H.No. 56, Krishna Path, Thrissur-511622   59.181.20.66
# 3            757\nDhawan Ganj\nBhubaneswar 919257   59.181.20.77
# 4  H.No. 837, Goyal Zila\nSultan Pur Majra 226998  59.181.20.184
#
#   india_country ip_from_sus_country sus_countries Two_FA sus_transaction_time  \
# 0         India     102.135.229.167         Nepal    yes          05:42:37 AM
# 1         India       176.32.194.21     Indonesia    yes          03:17:23 AM
# 2         India       176.58.234.43         Spain     no          03:22:21 AM
# 3         India        103.9.20.143    Mauritania    yes          05:19:36 AM
# 4         India     213.157.116.137       Georgia     no          04:07:13 AM
#
#   users_frequent_timeofpurchse high_transaction_after_suspicion  \
# 0                 08:27:01: PM                              yes
# 1                 07:43:38: PM                               no
# 2                 09:14:59: PM                               no
# 3                 08:37:42: PM                              yes
# 4                 11:01:52: PM                               no
#
#   customer_alert                       trandaction_location  \
# 0            yes           640, Mahajan Zila\nNanded-609745
# 1            yes                  34, Doshi\nSasaram-922659
# 2             no      33/64, Bhatt Circle\nChinsurah-981958
# 3             no      H.No. 193, Madan Street, Salem 069835
# 4             no  H.No. 53\nAnand Nagar\nMiryalaguda-210843
#
#                             current_location using_vpn  failed_logins     otp  \
# 0        862\nSeth Chowk, Vasai-Virar-530922       yes              4  931590
# 1          23/392, Dewan Path\nOngole-526288        no              0  573006
# 2   H.No. 90, Chauhan Chowk, Gopalpur-016300        no              4  828902
# 3  00/25\nBalakrishnan Marg, Kottayam-592636       yes              4  693815
# 4             099\nDhar Chowk\nNagaon-845031        no              0  950565
#
#   is_sus transaction_date
# 0     no       26/04/2024
# 1     no       22/03/2024
# 2     no       24/08/2023
# 3     no       20/02/2023
# 4     no       21/04/2024

# %%
df.corr()
# Out:
# <ipython-input-30-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Cards       CVV  failed_logins       otp
# Cards          1.000000  0.001103       0.017925  0.087748
# CVV            0.001103  1.000000      -0.009866  0.009881
# failed_logins  0.017925 -0.009866       1.000000 -0.016739
# otp            0.087748  0.009881      -0.016739  1.000000

# %%
def extract(col):
  if isinstance(col, str):
    match = re.search('\d{6}$',col)
    if match is not None:
      return match.group()
    return col
df['Billing_Address'] = df['Billing_Address'].apply(extract)

# %%
def extract(col):
  if isinstance(col, str):
    match = re.search('\d{6}$',col)
    if match is not None:
      return match.group()
    return col
df['provided_address'] = df['provided_address'].apply(extract)

# %%
def extract(col):
  if isinstance(col, str):
    match = re.search('\d{6}$',col)
    if match is not None:
      return match.group()
    return col
df['trandaction_location'] = df['trandaction_location'].apply(extract)

# %%
def extract(col):
  if isinstance(col, str):
    match = re.search('\d{6}$',col)
    if match is not None:
      return match.group()
    return col
df['current_location'] = df['current_location'].apply(extract)

# %%
check = df['Cardholder_Name'].value_counts()

# %%
df[df['Cardholder_Name'].isin(check[check >= 2].index)]
# Out:
#     Cardholder_Name             Cards   card_type  CVV Expiration_Date  \
# 305      Rohan Dave  6471955034587651    Discover  104           11/28
# 402    Lagan Thaman  4659215999778363        Visa  450           09/32
# 446   Mohanlal Behl   454786817330903        Amex  340           12/33
# 506       Myra Lata  6029583968990988    Discover  847           06/26
# 549   Manjari Ghosh  4938494786737936        Visa  541           03/32
# 628   Manjari Ghosh  6630076821300388    Discover  140           02/31
# 706    Lagan Thaman  5993362015626738  MasterCard  627           06/29
# 750      Rohan Dave   471155378437336        Amex  113           08/33
# 797   Mohanlal Behl  6305458391511398    Discover  430           02/25
# 890       Myra Lata  4825288845803786        Visa  650           05/33
#
#     Billing_Address provided_address       ip_india india_country  \
# 305          029756           073310  59.181.20.162         India
# 402          267714           834095    59.181.20.0         India
# 446          473532           947961  59.181.20.157         India
# 506          379177           914416   59.181.20.10         India
# 549          955859           129051   59.181.20.28         India
# 628          089402           716557  59.181.20.169         India
# 706          719012           276835   59.181.20.29         India
# 750          109305           968003  59.181.20.109         India
# 797          597323           637769   59.181.20.95         India
# 890          052663           743956  59.181.20.196         India
#
#     ip_from_sus_country                     sus_countries Two_FA  \
# 305       209.59.105.40                            Jersey    yes
# 402      41.202.216.132   Micronesia, Federated States of     no
# 446      190.113.87.194                       Netherlands     no
# 506       103.237.80.37                  Saint Barthélemy    yes
# 549        213.55.89.12                              Mali    yes
# 628     185.168.168.175                             India     no
# 706      131.100.31.103                        Seychelles     no
# 750       38.54.116.212  Saint Vincent and the Grenadines    yes
# 797       203.83.49.196                           Denmark    yes
# 890     195.139.169.200  Lao People's Democratic Republic     no
#
#     sus_transaction_time users_frequent_timeofpurchse  \
# 305          04:45:16 AM                 11:40:46: PM
# 402          02:13:27 AM                 11:17:35: PM
# 446          04:46:46 AM                 10:23:57: PM
# 506          04:33:21 AM                 11:36:35: PM
# 549          03:57:40 AM                 08:54:50: PM
# 628          02:43:43 AM                 10:50:58: PM
# 706          05:11:45 AM                 11:31:32: PM
# 750          05:46:03 AM                 10:32:04: PM
# 797          03:31:57 AM                 07:44:39: PM
# 890          04:59:31 AM                 08:25:35: PM
#
#     high_transaction_after_suspicion customer_alert trandaction_location  \
# 305                              yes            yes               828101
# 402                              yes             no               784808
# 446                               no            yes               612287
# 506                              yes            yes               135776
# 549                               no             no               536698
# 628                              yes             no               695429
# 706                               no             no               691389
# 750                               no            yes               551661
# 797                              yes            yes               808861
# 890                               no            yes               206881
#
#     current_location using_vpn  failed_logins     otp is_sus transaction_date
# 305           533439        no              3  868880     no       14/11/2024
# 402           954625        no              5  196158     no       12/09/2024
# 446           287950        no              4  585569     no       11/04/2024
# 506           743029        no              5  835544     no       31/05/2023
# 549           669502       yes              0  573786     no       18/12/2023
# 628           807241        no              2  504630     no       09/12/2023
# 706           618689        no              3  372303     no       20/02/2024
# 750           200480        no              4  318972     no       15/06/2023
# 797           987802        no              2  473047     no       09/12/2023
# 890           505666        no              2  284737     no       24/08/2024

# %%
'''df['transaction_date'] = df['transaction_date'].str.replace("\['",'').str.replace("\']",'')'''
# Out:
# 'df[\'transaction_date\'] = df[\'transaction_date\'].str.replace("\\[\'",\'\').str.replace("\']",\'\')'

# %%
'''df['day'],df['month'],df['year'] = df['transaction_date'].str.split('/',2).str'''
# Out:
# "df['day'],df['month'],df['year'] = df['transaction_date'].str.split('/',2).str"

# %%
df.corr()
# Out:
# <ipython-input-39-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Cards       CVV  failed_logins       otp
# Cards          1.000000  0.001103       0.017925  0.087748
# CVV            0.001103  1.000000      -0.009866  0.009881
# failed_logins  0.017925 -0.009866       1.000000 -0.016739
# otp            0.087748  0.009881      -0.016739  1.000000

# %%
def impute(col):
  if isinstance(col,str):
    if col == 'India':
      return 1
    else:
      return col
df['india_country'] = df['india_country'].apply(impute)

# %%
'''df['Expiration_Date'] = df['Expiration_Date'].astype(str)'''
# Out:
# "df['Expiration_Date'] = df['Expiration_Date'].astype(str)"

# %%
'''_,df['Expiration_Date_year'] = df['Expiration_Date'].str.split('/',1).str'''
# Out:
# "_,df['Expiration_Date_year'] = df['Expiration_Date'].str.split('/',1).str"

# %%
le = LabelEncoder()

# %%
transformed_Cards = le.fit_transform(df['Cards'])
df['Cards'] = transformed_Cards

# %%
transformed_card_type = le.fit_transform(df['card_type'])
df['card_type'] = transformed_card_type

# %%
transformed_Expiration_Date = le.fit_transform(df['Expiration_Date'])
df['Expiration_Date'] = transformed_Expiration_Date

# %%
transformed_Billing_Address = le.fit_transform(df['Billing_Address'])
df['Billing_Address'] = transformed_Billing_Address

# %%
transformed_provided_address = le.fit_transform(df['provided_address'])
df['provided_address'] = transformed_provided_address

# %%
transformed_ip_india = le.fit_transform(df['ip_india'])
df['ip_india'] = transformed_ip_india

# %%
transformed_ip_from_sus_country = le.fit_transform(df['ip_from_sus_country'])
df['ip_from_sus_country'] = transformed_ip_from_sus_country

# %%
transformed_sus_countries = le.fit_transform(df['sus_countries'])
df['sus_countries'] = transformed_sus_countries

# %%
transformed_Two_FA = le.fit_transform(df['Two_FA'])
df['Two_FA'] = transformed_Two_FA

# %%
transformed_sus_transaction_time = le.fit_transform(df['sus_transaction_time'])
df['sus_transaction_time'] = transformed_sus_transaction_time

# %%
transformed_users_frequent_timeofpurchse = le.fit_transform(df['users_frequent_timeofpurchse'])
df['users_frequent_timeofpurchse'] = transformed_users_frequent_timeofpurchse

# %%
transformed_failed_logins = le.fit_transform(df['failed_logins'])
df['failed_logins'] = transformed_failed_logins

# %%
transformed_high_transaction_after_suspicion = le.fit_transform(df['high_transaction_after_suspicion'])
df['high_transaction_after_suspicion'] = transformed_high_transaction_after_suspicion

# %%
transformed_customer_alert = le.fit_transform(df['customer_alert'])
df['customer_alert'] = transformed_customer_alert

# %%
transformed_trandaction_location = le.fit_transform(df['trandaction_location'])
df['trandaction_location'] = transformed_trandaction_location

# %%
transformed_current_location = le.fit_transform(df['current_location'])
df['current_location'] = transformed_current_location

# %%
transformed_using_vpn = le.fit_transform(df['using_vpn'])
df['using_vpn'] = transformed_using_vpn

# %%
transformed_failed_logins = le.fit_transform(df['failed_logins'])
df['failed_logins'] = transformed_failed_logins

# %%
transformed_otp = le.fit_transform(df['otp'])
df['otp'] = transformed_otp

# %%
transformed_is_sus = le.fit_transform(df['is_sus'])
df['is_sus'] = transformed_is_sus

# %%
transformed_transaction_date = le.fit_transform(df['transaction_date'])
df['transaction_date'] = transformed_transaction_date

# %%
df.drop('Cardholder_Name',axis=1,inplace=True)

# %%
df.head()
# Out:
#    Cards  card_type  CVV  Expiration_Date  Billing_Address  provided_address  \
# 0    888          1  754                5              473               714
# 1    226          0  506               12              775               823
# 2    497          2  166              102               99               505
# 3    493          2  393              116              861               917
# 4    825          1  867              116              695               236
#
#    ip_india  india_country  ip_from_sus_country  sus_countries  Two_FA  \
# 0         4              1                    5            140       1
# 1       165              1                  171             96       1
# 2       215              1                  172            189       0
# 3       227              1                   75            127       1
# 4        94              1                  416             75       0
#
#    sus_transaction_time  users_frequent_timeofpurchse  \
# 0                   900                           285
# 1                   310                           133
# 2                   325                           420
# 3                   821                           311
# 4                   516                           773
#
#    high_transaction_after_suspicion  customer_alert  trandaction_location  \
# 0                                 1               1                   568
# 1                                 0               1                   921
# 2                                 0               0                   977
# 3                                 1               0                    60
# 4                                 0               0                   197
#
#    current_location  using_vpn  failed_logins  otp  is_sus  transaction_date
# 0               534          1              4  923       0               350
# 1               530          0              0  546       0               295
# 2                16          0              4  838       0               326
# 3               599          1              4  690       0               269
# 4               849          0              0  942       0               282

# %%
df.corr()

# %%
x = df.drop('is_sus',axis=1)

# %%
x

# %%
y = df['is_sus']

# %%
y

# %%
from sklearn.model_selection import train_test_split,cross_val_score,GridSearchCV

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8,random_state=31)

# %%
x_train

# %%
x_test.shape
# Out:
# (200, 21)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr1 = LogisticRegression()
lr2 = LogisticRegression(C = 100, penalty ='l2', solver = 'liblinear')
lr3 = LogisticRegression()

# %%
lr1.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred1 = lr1.predict(x_test)

# %%
lr2.fit(x_train,y_train)
# Out:
# LogisticRegression(C=100, solver='liblinear')

# %%
y_pred2 = lr2.predict(x_test)

# %%
lr3.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred3 = lr3.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
print(f'y_pred1 = {accuracy_score(y_test,y_pred1)}')
# Out:
# y_pred1 = 0.925

# %%
confusion_matrix(y_test,y_pred1)
# Out:
# array([[185,   3],
#        [ 12,   0]])

# %%
print(f'y_pred2 = {accuracy_score(y_test,y_pred2) * 100}%')
# Out:
# y_pred2 = 100.0%

# %%
confusion_matrix(y_test,y_pred2)
# Out:
# array([[188,   0],
#        [  0,  12]])

# %%
print(f'y_pred3 = {accuracy_score(y_test,y_pred3)}')
# Out:
# y_pred3 = 0.925

# %%
confusion_matrix(y_test,y_pred3)
# Out:
# array([[185,   3],
#        [ 12,   0]])

# %%
param_grid = {'penalty': ['l1', 'l2'], 'solver': ['liblinear'], 'C': [0.001, 0.01, 0.1, 1, 10, 100]}

# %%
grid_search = GridSearchCV(lr1,param_grid,cv=5)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'penalty': ['l1', 'l2'], 'solver': ['liblinear']})

# %%
print(grid_search.best_params_)
# Out:
# {'C': 100, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
cross_val_score(lr1,x,y,cv=5,scoring='accuracy').mean() * 100
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 93.30000000000001
